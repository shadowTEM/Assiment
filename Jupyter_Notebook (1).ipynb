# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>"My Jupyter Notebook on IBM Watson Studio"</h1>

# %% [markdown]
# <strong>Youssef salah</strong><br>
# I want to be a data scientist

# %% [markdown]
# <em>i am interested in data science because I want to create my own AI models so i can process data to explain why this is the best decistion and i would like to make chat bots as well</em>

# %% [markdown]
# <h3>It add 3 and 4

# %%
3+4
# Out:
# 7

# %% [markdown]
# <ul>
#     <li> I
#     <li> Love
#     <li> Data
# </ul>
# <ol>
#     <li> One
#     <li> two
#     <li> three
# </ol>
# <img src="https://dazedimg-dazedgroup.netdna-ssl.com/900/azure/dazed-prod/1270/8/1278472.jpg" alt="joker">
#
# <a href = "https://www.google.com/search?q=joker&rlz=1C1CHWL_enEG930EG930&sxsrf=ALiCzsZYwuliCjBSfWzvjk2aFuX_bXVX6A:1662968807894&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjwpcTI4Y76AhVtgv0HHXQuB9wQ_AUoAXoECAEQAw&biw=1920&bih=912&dpr=1">joker images</a>
